# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv
# %matplotlib inline

# %%
df = pd.read_csv("D:\GitHub desktop\Housing\House.csv")

# %%
df['price-toman'] = df['price'] * 500

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    price-toman
# 0   6650000000
# 1   6125000000
# 2   6125000000
# 3   6107500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
#  13  price-toman       545 non-null    int64
# dtypes: int64(7), object(7)
# memory usage: 59.7+ KB

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# price-toman          int64
# dtype: object

# %%
categorical_columns = set(df.columns) - {'price', 'area','price-toman', 'price-usa'}

for col in categorical_columns:
    df[col] = df[col].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    category
#  3   bathrooms         545 non-null    category
#  4   stories           545 non-null    category
#  5   mainroad          545 non-null    category
#  6   guestroom         545 non-null    category
#  7   basement          545 non-null    category
#  8   hotwaterheating   545 non-null    category
#  9   airconditioning   545 non-null    category
#  10  parking           545 non-null    category
#  11  prefarea          545 non-null    category
#  12  furnishingstatus  545 non-null    category
#  13  price-toman       545 non-null    int64
# dtypes: category(11), int64(3)
# memory usage: 20.4 KB

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# price-toman         0
# price-usa           0
# dtype: int64

# %%
sns.displot(
    data=df,
    x='price',
    
)

# %%
df.price.min()
# Out:
# np.int64(1750000)

# %%
df.price.max()
# Out:
# np.int64(13300000)

# %%
sns.displot(
    data=df,
    x='price-toman',
    hue='furnishingstatus',
    palette='Dark2'  
)
plt.title('price-toman vs furnishingstatus')
# Out:
# Text(0.5, 1.0, 'price-toman vs furnishingstatus')

# %%
sns.displot(
    data=df,
    x='area',
    hue='furnishingstatus',
    palette='Dark2'
)
plt.title('price-toman vs area')
# Out:
# Text(0.5, 1.0, 'price-toman vs area')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='furnishingstatus',
    palette='Dark2'
)
g.figure.axes[0].set_xlim(1000, 7500)
plt.title('area vs furnishingstatus')
# Out:
# Text(0.5, 1.0, 'area vs furnishingstatus')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='furnishingstatus',
    palette='Dark2'
)
g.figure.axes[0].set_xlim(7600, 10000)
plt.title('area vs furnishingstatus')
# Out:
# Text(0.5, 1.0, 'area vs furnishingstatus')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='furnishingstatus',
    palette='Dark2'
)
g.figure.axes[0].set_xlim(11000, 17000)
plt.title('area vs furnishingstatus')
# Out:
# Text(0.5, 1.0, 'area vs furnishingstatus')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='bathrooms',
    palette='Dark2'
)
plt.title('area vs bathrooms')
# Out:
# Text(0.5, 1.0, 'area vs bathrooms')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='bathrooms',
    palette='Dark2'
)
plt.title('area vs bathrooms')
g.figure.axes[0].set_xlim(1000, 11000)
# Out:
# (1000.0, 11000.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='bathrooms',
    palette='Dark2'
)
plt.title('area vs bathrooms')
g.figure.axes[0].set_xlim(11000, 16500)
# Out:
# (11000.0, 16500.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='prefarea',
    palette='Dark2'
)
plt.title('area vs prefarea')
g.figure.axes[0].set_xlim(1000,7500)
# Out:
# (1000.0, 7500.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='prefarea',
    palette='Dark2'
)
plt.title('area vs prefarea')
g.figure.axes[0].set_xlim(7600,11000)
# Out:
# (7600.0, 11000.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='prefarea',
    palette='Dark2'
)
plt.title('area vs prefarea')
g.figure.axes[0].set_xlim(11000,16500)
# Out:
# (11000.0, 16500.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='bedrooms',
     palette='Dark2'
)
plt.title('area vs bedrooms')
# Out:
# Text(0.5, 1.0, 'area vs bedrooms')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='bedrooms',
     palette='Dark2'
)
plt.title('area vs bedrooms')
g.figure.axes[0].set_xlim(11000,16500)
# Out:
# (11000.0, 16500.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='stories',
     palette='Dark2'
)
plt.title('area vs stories')
g.figure.axes[0].set_xlim(11000,16500)
# Out:
# (11000.0, 16500.0)

# %%
sns.displot(
    data=df,
    x='area',
    hue='mainroad',
    palette='Dark2'
)
plt.title('area vs mainroad')
# Out:
# Text(0.5, 1.0, 'area vs mainroad')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='guestroom',
    palette='Dark2'
)
plt.title('area vs guestroom')
# Out:
# Text(0.5, 1.0, 'area vs guestroom')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='guestroom',
    palette='Dark2'
)
plt.title('area vs guestroom')
g.figure.axes[0].set_xlim(1000,8000)
# Out:
# (1000.0, 8000.0)

# %%
sns.displot(
    data=df,
    x='area',
    hue='basement',
    palette='Dark2'
)
plt.title('area vs basement')
# Out:
# Text(0.5, 1.0, 'area vs basement')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='hotwaterheating',
    palette='Dark2'
)
plt.title('area vs hotwaterheating')
# Out:
# Text(0.5, 1.0, 'area vs hotwaterheating')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='parking',
    palette='Dark2'
)
plt.title('area vs parking')
# Out:
# Text(0.5, 1.0, 'area vs parking')

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='parking',
    palette='Dark2'
)
plt.title('area vs parking')
g.figure.axes[0].set_xlim(1000,7000)
# Out:
# (1000.0, 7000.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='parking',
    palette='Dark2'
)
plt.title('area vs parking')
g.figure.axes[0].set_xlim(7700,10900)
# Out:
# (7700.0, 10900.0)

# %%
g = sns.displot(
    data=df,
    x='area',
    hue='parking',
    palette='Dark2'
)
plt.title('area vs parking')
g.figure.axes[0].set_xlim(11000,16500)
# Out:
# (11000.0, 16500.0)

# %%
df[df['bedrooms'] == 1]
# Out:
#        price  area bedrooms bathrooms stories mainroad guestroom basement  \
# 445  3150000  3450        1         1       1      yes        no       no
# 528  2275000  3970        1         1       1       no        no       no
#
#     hotwaterheating airconditioning parking prefarea furnishingstatus  \
# 445              no              no       0       no        furnished
# 528              no              no       0       no      unfurnished
#
#      price-toman     price-usa
# 445   1575000000  37951.807229
# 528   1137500000  27409.638554

# %%
df[df['bedrooms'] == 6]
# Out:
#        price  area bedrooms bathrooms stories mainroad guestroom basement  \
# 112  6083000  4300        6         2       2      yes        no       no
# 395  3500000  3600        6         1       2      yes        no       no
#
#     hotwaterheating airconditioning parking prefarea furnishingstatus  \
# 112              no              no       0       no        furnished
# 395              no              no       1       no      unfurnished
#
#      price-toman     price-usa
# 112   3041500000  73289.156627
# 395   1750000000  42168.674699

# %%
sns.regplot(
    data=df,
    x='area',
    y='price-toman',
    scatter_kws={'alpha':0.1, 's':50},
)
sns.regplot(
    data=df[~df['bedrooms'].isin([6, 1])],
    x='area',
    y='price-toman',
    scatter=False
)
plt.title('area vs price-toman With rows that have a number of bedrooms = 6 or 1'  )
# Out:
# Text(0.5, 1.0, 'area vs price-toman With rows that have a number of bedrooms = 6 or 1')

# %%
plt.Figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.title('basement vs price-toman')
sns.boxplot(x=df.basement, y=df.price, palette=("cubehelix"))


plt.subplot(1, 2, 2)
plt.title('hotwaterheating vs price-toman')
sns.boxplot(x=df.hotwaterheating, y=df.price, palette=("PuBuGn"))

plt.show()
# Out:
# C:\Users\mahdi\AppData\Local\Temp\ipykernel_3316\3872929346.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df.basement, y=df.price, palette=("cubehelix"))
# C:\Users\mahdi\AppData\Local\Temp\ipykernel_3316\3872929346.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df.hotwaterheating, y=df.price, palette=("PuBuGn"))

# %%
sns.catplot(
    data=df,
    x='parking',
    y='price-toman',
    kind='strip'
)
plt.title('parking vs price-toman')
# Out:
# Text(0.5, 1.0, 'parking vs price-toman')

# %%
for col in categorical_columns:
    df[col] = df[col].cat.codes

# %%
g = sns.heatmap(
    df.corr(),
    annot=True,
    fmt='.2f',
    cmap='Reds',
    annot_kws={'size':6}

)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  r2_score

df = pd.read_csv("D:\GitHub desktop\Housing\House.csv")
df['price-toman'] = df['price'] * 500
df['area'] = df['area'] / 1000

for col in categorical_columns:
    df[col] = df[col].astype('category').cat.codes

df = df[~df['bedrooms'].isin([6, 1])]

x = df.drop(columns=['price-toman'])
y = df['price-toman']

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

model = RandomForestRegressor()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)


r2 = r2_score(y_test, y_pred)
print(f'R2 Score : {r2}')
# Out:
# R2 Score : 0.9932963136315415

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


df = pd.read_csv("D:\GitHub desktop\Housing\House.csv")
df['price-toman'] = df['price'] * 500
df['area'] = df['area'] / 1000

for col in categorical_columns:
    df[col] = df[col].astype('category').cat.codes

df = df[~df['bedrooms'].isin([6, 1])]

x = df.drop(columns=['price'])
y = df['price-toman']

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
print(f'R2 Score : {r2}')
# Out:
# R2 Score : 1.0
